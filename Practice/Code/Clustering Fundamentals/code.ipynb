# %% [markdown]
# ## K-Means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
# X,y  = make_blobs?

# %%
X,y = make_blobs(n_samples=500,n_features=2,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
X.shape[0]
# Out:
# 500

# %%
k = 5
color = ["green","red","blue","yellow","orange"]

clusters = {}

for i in range(k):
    center = 10*(2*np.random.random((X.shape[1],))-1)
    points = []
    cluster = {
        'center': center,
        'points': points,
        'color':color[i]
    }
    clusters[i] = cluster

# %%
clusters
# Out:
# {0: {'center': array([7.58234623, 5.81701188]),
#   'points': [],
#   'color': 'green'},
#  1: {'center': array([-6.8186293 ,  2.94706668]),
#   'points': [],
#   'color': 'red'},
#  2: {'center': array([6.52317459, 9.89156293]), 'points': [], 'color': 'blue'},
#  3: {'center': array([ 0.57206415, -9.64179102]),
#   'points': [],
#   'color': 'yellow'},
#  4: {'center': array([9.19342587, 9.915638  ]),
#   'points': [],
#   'color': 'orange'}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
# Assign every data point to one clusters
def assignPointToClusters(clusters): # E-Step
    for ix in range(X.shape[0]):
        dist = []
        curr_x = X[ix]

        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)
        current_cluster = np.argmin(dist)
        clusters[current_cluster]['points'].append(curr_x)

def updateClusters(clusters): # M-Step -> We update every cluster center according to the mean of the points
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        if pts.shape[0]>0: # If a center is nonzero
            new_u = pts.mean(axis = 0)
            clusters[kx]['center'] = new_u
            clusters[kx]['points'] = [] # clear the list

def plotClusters(clusters):
    for kx in range(k):
        pts = np.array(clusters[kx]['points'])
        print(pts.shape)

        try:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
        except:
            pass

        # Plot the cluster center
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker="*")

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (100, 2)
# (300, 2)
# (32, 2)
# (39, 2)
# (29, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (99, 2)
# (198, 2)
# (49, 2)
# (103, 2)
# (51, 2)

# %%
def sumOfEncryptedInt(nums):
    sum = 0
    for i in nums:
        sum = sum + encrypt(i)
    return sum

def encrypt(n) -> int:
    if int(n/10) != 0:
        pass
    else:
        return n

# %%
nums = [1,2,3,4,54]
sumOfEncryptedInt(nums)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 nums = [1,2,3,4,54]
# ----> 2 sumOfEncryptedInt(nums)
#
# Cell In[12], line 4, in sumOfEncryptedInt(nums)
#       2 sum = 0
#       3 for i in nums:
# ----> 4     sum = sum + encrypt(i)
#       5 return sum
#
# TypeError: unsupported operand type(s) for +: 'int' and 'NoneType'

# %%
temp=[]
nums = 4,5,6,7,7,9
for i in str(nums):
    temp1 = int(i)
    temp.append(temp1)
temp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 4
#       2 nums = 4,5,6,7,7,9
#       3 for i in str(nums):
# ----> 4     temp1 = int(i)
#       5     temp.append(temp1)
#       6 temp
#
# ValueError: invalid literal for int() with base 10: '('

# %%
int(i) for i
